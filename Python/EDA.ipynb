# %% [markdown]
# # Exploratory Data Analysis - DS Salaries
# In this notebook, we explore the cleaned dataset to find trends and patterns.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../Dataset/Cleaned_Data.csv')
df.head()

# %% [markdown]
# ## Descriptive Statistics

# %%
df.describe()
