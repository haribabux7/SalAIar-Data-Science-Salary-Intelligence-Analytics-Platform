# %% [markdown]
# # Data Cleaning
# Processing the raw DS salaries dataset for analysis.

# %%
import pandas as pd
df = pd.read_csv('../Dataset/Raw_Data.csv')
df_cleaned = df.drop_duplicates()
df_cleaned.to_csv('../Dataset/Cleaned_Data.csv', index=False)
